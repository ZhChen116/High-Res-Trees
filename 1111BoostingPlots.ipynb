# %%
import matplotlib.pyplot as plt

# Data for Mean, CP, and Tucker training and testing RMSE values
mean_train_rmse = [1.0, 0.8105215915498751, 0.6569297207158584, 0.5324129083508344, 0.4315536196883042, 
                   0.34980487463200205, 0.28355359908949146, 0.22985814812167069, 0.1863263028026042,
                   0.1511126314969908, 0.12251349456374495, 0.09933116046883236, 0.08053824678570766, 
                   0.06531199799012152, 0.05296444375579372, 0.042960524836346485, 0.03486158436041225,
                   0.028293082262016874, 0.02296596036870635, 0.018645887498186867]

mean_test_rmse = [1.00076877504258, 0.9482101542535966, 0.9207351729516963, 0.8992848743550766, 0.8805128672705573, 
                  0.8674499518609213, 0.8455573195542253, 0.8330276385590084, 0.8168873175904401, 0.8055666294707357,
                  0.7923810207627273, 0.781191524584505, 0.7727117136837762, 0.7658073006256174, 0.7617405195499645,
                  0.7611513163496819, 0.7535512446621278, 0.7490900046840785, 0.7458551124848047, 0.7443783365503555]

cp_train_rmse = [1.0, 0.957940968008816, 0.920701721583704, 0.887454054974455, 0.8591455859170838, 
                 0.8320804544883991, 0.8080686864705774, 0.7883032758988089, 0.7693715792801945, 0.7539491561723015,
                 0.7379921541903219, 0.722217981346735, 0.7085232333781251, 0.6952638897586314, 0.68098677563911,
                 0.6690740997251695, 0.6571100667132904, 0.6463346227657926, 0.6355622448601185, 0.6253513345325774]

cp_test_rmse = [1.00076877504258, 0.9564485468261678, 0.9274658594904216, 0.901429524470312, 0.8822077924713436, 
                0.8583100040015815, 0.847303535741487, 0.8392745562699728, 0.8283219154785155, 0.8188310520991802,
                0.8120693249440591, 0.8032023149021025, 0.7978204058441716, 0.7936742569892886, 0.7870496970995107,
                0.7771970105409938, 0.7802033863113421, 0.7748172115414786, 0.7676302652636559, 0.7666734772168604]

tucker_train_rmse = [1.0, 0.8105272687923981, 0.6570157960525508, 0.532625317936345, 0.43176825800758933, 
                     0.3500458333394243, 0.2837929178674432, 0.23009813150940506, 0.18658420261812528, 0.15128888764530746,
                     0.12269278546545895, 0.09950231640892689, 0.08070184399418452, 0.06545844128597542, 0.053098947961537,
                     0.04308155645207758, 0.034965755863478845, 0.028383069412200472, 0.02304332350301039, 0.01871192184431028]

tucker_test_rmse = [1.00076877504258, 0.9670710313104134, 0.9149746724107072, 0.8850289506143539, 0.8652493782426423, 
                    0.8382410450697384, 0.8244312370242178, 0.8065415542404513, 0.7983879863941619, 0.7873548821494096,
                    0.7757443365143378, 0.7650694233394174, 0.7547272552040161, 0.7458334499329076, 0.7385634454949297,
                    0.7360071235191431, 0.7318608953748611, 0.7283921118779034, 0.7256987337944834, 0.7240472185221107]

# Define x-axis values (iterations)
iterations = range(1, 21)

# Plot RMSE traces
plt.figure(figsize=(10, 6))

# Plot Mean RMSE
plt.plot(iterations, mean_train_rmse, marker='o', label='Mean Train RMSE', color='blue')
plt.plot(iterations, mean_test_rmse, marker='x', linestyle='--', label='Mean Test RMSE', color='blue')

# Plot CP RMSE
plt.plot(iterations, cp_train_rmse, marker='o', label='CP Train RMSE', color='orange')
plt.plot(iterations, cp_test_rmse, marker='x', linestyle='--', label='CP Test RMSE', color='orange')

# Plot Tucker RMSE
plt.plot(iterations, tucker_train_rmse, marker='o', label='Tucker Train RMSE', color='green')
plt.plot(iterations, tucker_test_rmse, marker='x', linestyle='--', label='Tucker Test RMSE', color='green')

# Labeling the plot
plt.xlabel('Iterations')
plt.ylabel('RMSE')
plt.title('Training and Testing RMSE for Mean, CP, and Tucker Methods Over 20 Iterations')
plt.legend()
plt.grid(True)
plt.show()
